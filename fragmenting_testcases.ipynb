# %%
import fragfinder
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

smile = 'c1cc(oc1)[C@H](CNC(=O)[C@H]2CCCN(C2)C(=O)N3CCCC3)[NH+]4CCCC4'

fragments = fragfinder.identify_fragments(smile)

Draw.MolToImage(Chem.MolFromSmiles(smile))
# Out:
# 25
# [10:07:23] Running LargestFragmentChooser
# [10:07:23] Fragment: O=C(NC[C@@H](c1ccco1)[NH+]1CCCC1)[C@H]1CCCN(C(=O)N2CCCC2)C1
# [10:07:23] New largest fragment: O=C(NC[C@@H](c1ccco1)[NH+]1CCCC1)[C@H]1CCCN(C(=O)N2CCCC2)C1 (61)
# [10:07:23] Running LargestFragmentChooser
# [10:07:23] Fragment: CCNC=O
# [10:07:23] New largest fragment: CCNC=O (12)
# [10:07:23] Running LargestFragmentChooser
# [10:07:23] Fragment: C=O
# [10:07:23] New largest fragment: C=O (4)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
fragments
# Out:
#                Smiles                                       Molecule  \
# 0  *[C@@H](*)CNC(*)=O  <rdkit.Chem.rdchem.Mol object at 0x176927f40>
# 1    *[C@H]1CCCN(*)C1  <rdkit.Chem.rdchem.Mol object at 0x17697c0b0>
# 2            *c1ccco1  <rdkit.Chem.rdchem.Mol object at 0x17697c190>
# 3            *N1CCCC1  <rdkit.Chem.rdchem.Mol object at 0x17697c2e0>
# 4        *[NH+]1CCCC1  <rdkit.Chem.rdchem.Mol object at 0x17697c430>
# 5                 *CC  <rdkit.Chem.rdchem.Mol object at 0x17697c040>
# 6             *C(*)=O  <rdkit.Chem.rdchem.Mol object at 0x17697c510>
# 7            *NC(*)=O  <rdkit.Chem.rdchem.Mol object at 0x17697c890>
#
#                                                  xyz  numAttachments
# 0  12\n\nAt    -1.687835    1.906387   -1.088388\...               3
# 1  17\n\nAt     3.308131   -0.933806   -0.699085\...               2
# 2  9\n\nAt     3.257096   -0.607179    0.287368\n...               1
# 3  14\n\nAt     3.210134    0.264149   -0.039543\...               1
# ...

# %%
Draw.MolToImage(Chem.MolFromSmiles('NCC(C(=O)N)C'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
